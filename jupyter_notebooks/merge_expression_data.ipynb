# %%
import pandas as pd

# %%
# List of expression data file paths
file_paths = [
    "/scratch/hb-functionalgenomics/projects/gut-bulk/ongoing/2024-02-07-GutPublicRNASeq/00-Final_files/expression_data/ERP109626/9_covariate_correction/ERP109626_gene_counts-TMM.SampleSelection.ProbesWithZeroVarianceRemoved.Log2Transformed.forcenormal.covariatecorrected.txt.gz.CovariatesRemovedOLS.txt.gz",
    "/scratch/hb-functionalgenomics/projects/gut-bulk/ongoing/2024-02-07-GutPublicRNASeq/00-Final_files/expression_data/ERP113396/9_covariate_correction/allStudiesCombined_gene_counts-TMM.SampleSelection.ProbesWithZeroVarianceRemoved.Log2Transformed.forcenormal.covariatecorrected.txt.gz.CovariatesRemovedOLS.txt.gz",
    "/scratch/hb-functionalgenomics/projects/gut-bulk/ongoing/2024-02-07-GutPublicRNASeq/00-Final_files/expression_data/ERP114636/9_covariate_correction/allStudiesCombined_gene_counts-TMM.SampleSelection.ProbesWithZeroVarianceRemoved.Log2Transformed.forcenormal.covariatecorrected.txt.gz.CovariatesRemovedOLS.txt.gz",
    "/scratch/hb-functionalgenomics/projects/gut-bulk/ongoing/2024-02-07-GutPublicRNASeq/00-Final_files/expression_data/SRP063496/9_covariate_correction/allStudiesCombined_gene_counts-TMM.SampleSelection.ProbesWithZeroVarianceRemoved.Log2Transformed.forcenormal.covariatecorrected.txt.gz.CovariatesRemovedOLS.txt.gz",
    "/scratch/hb-functionalgenomics/projects/gut-bulk/ongoing/2024-02-07-GutPublicRNASeq/00-Final_files/expression_data/SRP068609/9_covariate_correction/allStudiesCombined_gene_counts-TMM.SampleSelection.ProbesWithZeroVarianceRemoved.Log2Transformed.forcenormal.covariatecorrected.txt.gz.CovariatesRemovedOLS.txt.gz",
    "/scratch/hb-functionalgenomics/projects/gut-bulk/ongoing/2024-02-07-GutPublicRNASeq/00-Final_files/expression_data/SRP076426/9_covariate_correction/allStudiesCombined_gene_counts-TMM.SampleSelection.ProbesWithZeroVarianceRemoved.Log2Transformed.forcenormal.covariatecorrected.txt.gz.CovariatesRemovedOLS.txt.gz",
    "/scratch/hb-functionalgenomics/projects/gut-bulk/ongoing/2024-02-07-GutPublicRNASeq/00-Final_files/expression_data/SRP077046/9_covariate_correction/allStudiesCombined_gene_counts-TMM.SampleSelection.ProbesWithZeroVarianceRemoved.Log2Transformed.forcenormal.covariatecorrected.txt.gz.CovariatesRemovedOLS.txt.gz",
    "/scratch/hb-functionalgenomics/projects/gut-bulk/ongoing/2024-02-07-GutPublicRNASeq/00-Final_files/expression_data/SRP096757/9_covariate_correction/allStudiesCombined_gene_counts-TMM.SampleSelection.ProbesWithZeroVarianceRemoved.Log2Transformed.forcenormal.covariatecorrected.txt.gz.CovariatesRemovedOLS.txt.gz",
    "/scratch/hb-functionalgenomics/projects/gut-bulk/ongoing/2024-02-07-GutPublicRNASeq/00-Final_files/expression_data/SRP125961/9_covariate_correction/allStudiesCombined_gene_counts-TMM.SampleSelection.ProbesWithZeroVarianceRemoved.Log2Transformed.forcenormal.covariatecorrected.txt.gz.CovariatesRemovedOLS.txt.gz",
    "/scratch/hb-functionalgenomics/projects/gut-bulk/ongoing/2024-02-07-GutPublicRNASeq/00-Final_files/expression_data/SRP129004/9_covariate_correction/allStudiesCombined_gene_counts-TMM.SampleSelection.ProbesWithZeroVarianceRemoved.Log2Transformed.forcenormal.covariatecorrected.txt.gz.CovariatesRemovedOLS.txt.gz",
    "/scratch/hb-functionalgenomics/projects/gut-bulk/ongoing/2024-02-07-GutPublicRNASeq/00-Final_files/expression_data/SRP155976/9_covariate_correction/allStudiesCombined_gene_counts-TMM.SampleSelection.ProbesWithZeroVarianceRemoved.Log2Transformed.forcenormal.covariatecorrected.txt.gz.CovariatesRemovedOLS.txt.gz",
    "/scratch/hb-functionalgenomics/projects/gut-bulk/ongoing/2024-02-07-GutPublicRNASeq/00-Final_files/expression_data/SRP189239/9_covariate_correction/allStudiesCombined_gene_counts-TMM.SampleSelection.ProbesWithZeroVarianceRemoved.Log2Transformed.forcenormal.covariatecorrected.txt.gz.CovariatesRemovedOLS.txt.gz"
]

# Read the first file into a DataFrame
merged_df = pd.read_csv(file_paths[0], index_col=0, sep="\t")

# Iterate over the remaining file paths and merge them into the DataFrame
for file_path in file_paths[1:]:
    df = pd.read_csv(file_path, index_col=0)
    merged_df = pd.merge(merged_df, df, left_index=True, right_index=True, how='outer')

# Save the merged DataFrame to a new file
merged_df.to_csv("/scratch/hb-functionalgenomics/projects/gut-bulk/ongoing/2024-02-07-GutPublicRNASeq/00-Final_files/merged_expression_data.txt.gz")

# %%
test = pd.read_csv("/scratch/hb-functionalgenomics/projects/gut-bulk/ongoing/2024-02-07-GutPublicRNASeq/00-Final_files/expression_data/ERP109626/9_covariate_correction/ERP109626_gene_counts-TMM.SampleSelection.ProbesWithZeroVarianceRemoved.Log2Transformed.forcenormal.covariatecorrected.txt.gz.CovariatesRemovedOLS.txt.gz", index_col=0, sep="\t")

# %%
test
# Out:
#                     ERR2675481  ERR2675447  ERR2675443  ERR2675441  \
# -
# ENSG00000107882.12    0.577883   -0.340591   -0.450463   -0.228352
# ENSG00000228657.1    -0.218758    0.197312   -0.013375    0.064699
# ENSG00000207029.1     0.328366   -0.280705    0.011127   -0.138079
# ENSG00000171206.16    0.095871   -0.148595   -0.136918   -0.082745
# ENSG00000272933.1    -0.230728    0.606782   -0.000687    0.191126
# ...                        ...         ...         ...         ...
# ENSG00000109466.14   -0.401627   -0.005492   -0.614329    0.221133
# ENSG00000200974.1     0.263804   -0.302615    0.012454   -0.092145
# ENSG00000229894.5    -0.639325    0.556717   -0.318312    0.361380
# ENSG00000052802.13   -0.632926    0.358775    0.870345    0.168785
# ENSG00000109472.14    0.367048    0.111752   -0.240413    0.061719
#
#                     ERR2675437  ERR2675430  ERR2675477  ERR2675479  \
# -
# ENSG00000107882.12   -0.548004    0.626490    0.593029   -0.099333
# ...
